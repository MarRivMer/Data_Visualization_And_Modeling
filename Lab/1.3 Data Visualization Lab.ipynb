# %% [markdown]
# # Lab Instructions
#
# You have been hired by a record executive to design a guaranteed smash hit song based on data.  The exec has decided that if you make a song that has all the most popular features of recent songs then it will definitely be a hit.  So if - for example - the most common key in the Spotify data is C# then we would want the song we are designing to also be in C#.  If a "typical" value of BPM is between 120 and 130 then we would want the song we are designing to also have a tempo between 120 and 130 BMP.
#
# Visualize and describe the distribution of:
# * BPM
# * Key
# * Mode
# * Danceability
# * Energy
# * Speechiness
# * Acousticness
#
# Based on your visualizations and calculations, what values for each of these features would make a song a guaranteed smash hit?  For quantitative features, you should propose a range of values.
#
# Identify if there are any songs in the Spotify dataset that meet all of the criteria we determined.  What is/are the artist(s) and title(s) of the song?  Were any of these songs actually popular?
#
# Pick a song that you know was a smash hit. How do the values of BPM, key, mode, danceability, etc. compare to other songs?
#
# **Hint:**  Import the Spotify data using `df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')`.

# %%
import pandas as pd

df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')
df.head()

# %%
df['bpm'].plot(kind='hist',
               title='BPM in Spotify Songs through 2023',
               xlabel='Beats Per Minute',
               ylabel='Number of Songs')

# %%
popular_subset = df.loc[ (df['key'] == 'A') &
                         (df['bpm'] < 100) &
                         (df['mode'] == 'Minor') ]
                        
    
popular_subset.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')

df.head()

# %%
df['bpm'].plot(
    kind='hist',
    bins=20,
    title='BPM Distribution',
    xlabel='Beats Per Minute',
    ylabel='Number of Songs'
)

plt.show()

# %%
df['key'].value_counts().plot(
    kind='bar',
    title='Most Common Song Keys',
    xlabel='Key',
    ylabel='Number of Songs'
)

plt.show()

# %%
df['mode'].value_counts().plot(
    kind='bar',
    title='Mode Distribution',
    xlabel='Mode',
    ylabel='Number of Songs'
)

plt.show()

# %%
df['danceability_%'].plot(
    kind='hist',
    bins=20,
    title='Danceability Distribution',
    xlabel='Danceability',
    ylabel='Number of Songs'
)

plt.show()

# %%
df['energy_%'].plot(
    kind='hist',
    bins=20,
    title='Energy Distribution',
    xlabel='Energy',
    ylabel='Number of Songs'
)

plt.show()

# %%
df['speechiness_%'].plot(
    kind='hist',
    bins=20,
    title='Speechiness Distribution',
    xlabel='Speechiness',
    ylabel='Number of Songs'
)

plt.show()

# %%
df['acousticness_%'].plot(
    kind='hist',
    bins=20,
    title='Acousticness Distribution',
    xlabel='Acousticness',
    ylabel='Number of Songs'
)

plt.show()

# %%
popular_subset = df.loc[
    (df['key'] == 'C#') &
    (df['bpm'] >= 110) &
    (df['bpm'] <= 130) &
    (df['mode'] == 'Major')
]

popular_subset.head()

# %% [markdown]
# Data Analysis Conclusion:
#
# I recognize every song in the popular subset list. All 5 songs are popular hits with 1 billion + streams. They have all reached top numbers in charts ranging in the top 100, are all composed in C# and Major, have 40+ energy and ranging acousticness. This leads me to the conclusion that the biggest smash hits and the "Garanteed Smash Hit" song are songs with great danceablity, great energy, composed in C# and Major and a bpm ranging of 110+. This is a perfect starting point to plan a song out and set it up for success.
#
#
#
# Personal Song Choice:

# %%
personal_song_choice = df.loc[df['track_name'] == 'WHERE SHE GOES']

personal_song_choice.head()

# %% [markdown]
# Smash Hits + Personal Song Choice Comparision:
#
# The song I picked was "WHERE SHE GOES" by Bad Bunny, I am Puerto Rican so Bad Bunny is an artist that represents my island. The popular hits and "WHERE SHE GOES" differ slightly but are very similar as well, They differ in Key and Mode, The song composed by Bad Bunny is composed in A and Major; however, every other value is the same, the song has great danceability, great energy, and a BPM of 144 which is greater than 110. The song has 300+ million streams so it is not as big as the popular smash hits maybe due to the fact that it was composed in A and Minor; however it is still considered a smash hit and one of my favorite songs.
